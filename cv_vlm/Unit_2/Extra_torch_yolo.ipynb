# %% [markdown]
# # Notebook that uses torch hub + Ultralytics YOLO Models
# ## PyTorch Implementation:
#
# For applications requiring YOLO implementations within a PyTorch environment, the Ultralytics organization provides a pre-trained (upto) YOLOv5 model readily accessible through the PyTorch Hub: https://pytorch.org/hub/ultralytics_yolov5/. This resource offers a convenient starting point for leveraging YOLOv5 functionalities.
#
# ## Version Availability:
#
# It's important to note that subsequent YOLO versions (beyond v5) developed by Ultralytics are not currently open-sourced. This implies that the specific model architectures and pre-trained weights associated with these later versions are not publicly available for unrestricted use or modification.

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images

# Inference
results = model(imgs)

# Results
results.print()
results.save()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]
# Out:
# /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/howt/.cache/torch/hub/master.zip
# Collecting ultralytics
#   Downloading ultralytics-8.2.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (5.9.8)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: six>=1.5 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/howt/miniforge3/envs/py311cv/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.0-py3-none-any.whl (750 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 6.6 MB/s eta 0:00:0000:0100:01m
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, thop, ultralytics
# Successfully installed py-cpuinfo-9.0.0 thop-0.1.1.post2209072238 ultralytics-8.2.0
# requirements: Ultralytics requirement ['gitpython>=3.1.30'] not found, attempting AutoUpdate...
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.5 MB/s eta 0:00:00a 0:00:01
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 12.8 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 smmap-5.0.1
#
# requirements: AutoUpdate success ✅ 2.5s, installed 1 package: ['gitpython>=3.1.30']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 2024-4-18 Python-3.11.8 torch-2.2.2+cu121 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 21.6MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1448.0ms pre-process, 129.5ms inference, 4.1ms NMS per image at shape (1, 3, 384, 640)
# Saved 1 image to runs/detect/exp2
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  743.290527   48.343628  1141.756592  720.000000    0.879861      0  person
# 1  441.989624  437.336670   496.585083  710.036255    0.675119     27     tie
# 2  123.051086  193.238098   714.690674  719.771301    0.666694      0  person
# 3  978.989807  313.579468  1025.302856  415.526184    0.261517     27     tie

# %%
# Predict with the model
results = model('https://ultralytics.com/images/bus.jpg')
